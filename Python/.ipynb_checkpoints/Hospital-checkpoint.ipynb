# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('Final_Monthly_Dataset.csv')
df.head()
# Out:
#        Date  Mean_Temp   Code                       Region  \
# 0  6/1/2015       15.6    NaN                          NaN
# 1  6/1/2015       15.6    RF4  London Commissioning Region
# 2  6/1/2015       15.6    R1H  London Commissioning Region
# 3  6/1/2015       15.6  AD913  London Commissioning Region
# 4  6/1/2015       15.6    RYX  London Commissioning Region
#
#                                                 Name  AE_Attendance_1  \
# 0                                            England          1249213
# 1  Barking, Havering And Redbridge University Hos...            18991
# 2                             Barts Health NHS Trust            27291
# 3                               Beckenham Beacon Ucc                0
# 4      Central London Community Healthcare NHS Trust                0
#
#    AE_Attendance_2  AE_Attendance_3  AE_Total_Attendance  \
# 0          53398.0           608598            1911209.0
# 1            569.0             2884              22444.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14024 entries, 0 to 14023
# Data columns (total 29 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Date                               14024 non-null  object
#  1   Mean_Temp                          14024 non-null  float64
#  2   Code                               13966 non-null  object
#  3   Region                             13966 non-null  object
#  4   Name                               14024 non-null  object
#  5   AE_Attendance_1                    14024 non-null  int64
#  6   AE_Attendance_2                    14024 non-null  float64
#  7   AE_Attendance_3                    14024 non-null  int64
#  8   AE_Total_Attendance                14024 non-null  float64
#  9   AE_Attendance_1_gt_4h              13870 non-null  float64
#  10  AE_Attendance_2_gt_4h              13870 non-null  float64
# ...

# %%
df.Code.value_counts()
# Out:
# RXL      58
# RA7      58
# RCB      58
# RJN      58
# RY2      58
#          ..
# ARN02     2
# NYM13     2
# NX123     2
# RT1       1
# NNF16     1
# Name: Code, Length: 309, dtype: int64

# %%
df[df.Code.isna() == True]
# Out:
#             Date  Mean_Temp Code Region     Name  AE_Attendance_1  \
# 0       6/1/2015       15.6  NaN    NaN  England          1249213
# 252     7/1/2015       14.6  NaN    NaN  England          1271523
# 505     8/1/2015       16.8  NaN    NaN  England          1215826
# 758     9/1/2015       17.1  NaN    NaN  England          1221594
# 1009   10/1/2015       19.3  NaN    NaN  England          1261395
# 1255   11/1/2015       18.4  NaN    NaN  England          1236294
# 1502   12/1/2015       22.1  NaN    NaN  England          1232965
# 1748    1/1/2016       23.1  NaN    NaN  England          1250005
# 1994    2/1/2016       22.7  NaN    NaN  England          1218372
# 2240    3/1/2016       21.6  NaN    NaN  England          1350373
# 2488    4/1/2016       20.4  NaN    NaN  England          1214057
# 2736    5/1/2016       18.3  NaN    NaN  England          1353206
# 2983    6/1/2016       17.3  NaN    NaN  England          1282499
# ...

# %%
# change the Date column to dattime format
df.Date = pd.to_datetime(df.Date, format="%d/%m/%Y")

# %%
df.head(1)
# Out:
#         Date  Mean_Temp Code Region     Name  AE_Attendance_1  \
# 0 2015-01-06       15.6  NaN    NaN  England          1249213
#
#    AE_Attendance_2  AE_Attendance_3  AE_Total_Attendance  \
# 0          53398.0           608598            1911209.0
#
#    AE_Attendance_1_gt_4h  ...  Other_Emergency_Admissions  \
# 0                96663.0  ...                      124809
#
#    Total_Emergency_Admissions  Patients_waiting_gt_4h_admission  \
# 0                      458790                             19065
#
#    Patients_waiting_gt_12h_admission  AE_Attendance_1_lt_4h  \
# 0                                 25                    NaN
#
#    AE_Attendance_2_lt_4h  AE_Attendance_3_lt_4h  AE_Total_Attendance_lt_4h  \
# 0                    NaN                    NaN                        NaN
#
#    AE_PercAttendance_2_gt_4h  AE_PercAttendance_3_gt_4h
# 0                        NaN                        NaN
#
# [1 rows x 29 columns]

# %%
# dataframe where code == NaN
x = df[df.Code.isna() == True]

# %%
# get the unique value of the Name for its corresponding code is NaN
uniqueName = pd.unique(x.Name)
uniqueName
# Out:
# array(['England'], dtype=object)

# %%
# group by Name
groupName = x.groupby(by='Name')

# %%
def populateCodeAndRegion(groupName, uniqueName):
    for i in range(len(uniqueName)):
        # for holding the 1st three letters of the Name
        Str = ''
        Str = uniqueName[i][:3]
        provideName = groupName.get_group(uniqueName[i])
        for j in provideName.index:
            df.loc[j, ["Code"]] = Str
            df.loc[j, ["Region"]] = Str+'_'+str(i)

# %%
populateCodeAndRegion(groupName, uniqueName)

# %%
df[['AE_Attendance_1_gt_4h','AE_Attendance_2_gt_4h','AE_Attendance_3_gt_4h','AE_Total_Attendance_gt_4h','AE_PercAttendance_1_gt_4h','AE_Total_PercAttendance_gt_4h','AE_Attendance_1_lt_4h', 'AE_Attendance_2_lt_4h','AE_Attendance_3_lt_4h','AE_Total_Attendance_lt_4h','AE_PercAttendance_2_gt_4h' ,'AE_PercAttendance_3_gt_4h']].describe()
# Out:
#        AE_Attendance_1_gt_4h  AE_Attendance_2_gt_4h  AE_Attendance_3_gt_4h  \
# count           13870.000000           13870.000000           13870.000000
# mean             1898.726460               4.747657              45.161932
# std             15170.371883              41.294397             389.744169
# min                 0.000000               0.000000               0.000000
# 25%                 0.000000               0.000000               0.000000
# 50%               423.000000               0.000000               0.000000
# 75%              1576.000000               0.000000               9.000000
# max            381612.000000            1099.000000           14682.000000
#
#        AE_Total_Attendance_gt_4h  AE_PercAttendance_1_gt_4h  \
# count               13870.000000                7813.000000
# mean                 1948.636049                   0.825440
# std                 15580.461073                   0.097583
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14024 entries, 0 to 14023
# Data columns (total 29 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Date                               14024 non-null  datetime64[ns]
#  1   Mean_Temp                          14024 non-null  float64
#  2   Code                               14024 non-null  object
#  3   Region                             14024 non-null  object
#  4   Name                               14024 non-null  object
#  5   AE_Attendance_1                    14024 non-null  int64
#  6   AE_Attendance_2                    14024 non-null  float64
#  7   AE_Attendance_3                    14024 non-null  int64
#  8   AE_Total_Attendance                14024 non-null  float64
#  9   AE_Attendance_1_gt_4h              13870 non-null  float64
#  10  AE_Attendance_2_gt_4h              13870 non-null  float64
# ...
